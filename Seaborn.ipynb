# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize =[4,2])
sns.histplot(tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
plt.figure(figsize =[4,2])
sns.histplot(tips['tip'],bins = 20, kde = True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
plt.figure(figsize =[4,2])
sns.histplot(tips['total_bill'],bins = 20, kde = True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
plt.figure(figsize =[3,2])
sns.countplot(data = tips,x ='time')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
plt.figure(figsize =[3,2])
sns.countplot(data = tips,x ='tip')
# Out:
# <Axes: xlabel='tip', ylabel='count'>

# %%
plt.figure(figsize =[3,2])
sns.barplot(data = tips,x = 'sex',y = 'tip')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
plt.figure(figsize =[3,2])
sns.countplot(data = tips,x ='sex',)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize =[3,2])
sns.histplot(tips['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
plt.figure(figsize =[3,2])
sns.countplot(data = tips,x ='day', palette = "magma")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
plt.figure(figsize =[3,2])
sns.boxplot(data = tips,x = 'day',y = 'tip',palette = "Paired")
#มันคือข้อมูลที่เรียกว่า นอยส์,เอาส์ไลเออร์หรือสิ่งรบกวน ข้อมูลที่กระโดดจากกลุ่มข้อมูล
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
plt.figure(figsize =[3,2])
sns.boxplot(data = tips,y = 'day',x = 'tip',palette = "Set2")
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.boxplot(data = tips)
# Out:
# <Axes: >

# %%
sns.boxplot(data = tips,x = 'day',y = 'tip',hue = 'sex',palette = "Set2")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
plt.figure(figsize =[3,2])
sns.violinplot(data = tips,x = 'day',y = 'tip',palette = "Set2")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
plt.figure(figsize =[4,3])
sns.violinplot(data = tips ,x = 'day',y = 'tip',hue ='sex',split ='True',palette = "tab10")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
plt.figure(figsize =[4,3])
sns.stripplot(data = tips,x = 'day',y = 'tip',hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
plt.figure(figsize =[4,3])
sns.stripplot(data = tips,x = 'day',y = 'tip',hue = 'sex',jitter = 0.2)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(data = tips,x = 'day',y = 'tip',hue = 'sex',palette = "Set2")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(data = tips,x = 'day',y = 'tip',palette = "husl")
sns.swarmplot(data = tips,x = 'day',y = 'tip',hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
plt.figure(figsize =[4,3])
sns.scatterplot(data = tips, x = 'total_bill' , y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize =[4,3])
sns.scatterplot(data = tips, x = 'total_bill' , y = 'tip',hue = 'sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize =[4,3])
sns.lineplot(data = tips, x = 'total_bill' , y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(data = tips, x = 'total_bill' , y = 'tip',hue = 'sex',palette = "husl") 
#เอาข้อมูลหลายตัวมารวมกัน

# %%
sns.jointplot(data = tips, x = 'total_bill' , y = 'tip',kind = 'hex')

# %%
sns.pairplot(data = tips)
# Out:
# C:\Users\natty\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(data = tips,hue = 'sex')
# Out:
# C:\Users\natty\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.JointGrid(data = tips, x = 'total_bill' , y = 'tip')

# %%
g = sns.JointGrid(data = tips, x = 'total_bill' , y = 'tip')
g.plot( sns.scatterplot, sns.boxplot )

# %%
g = sns.PairGrid(data = tips,hue = 'sex')
g.map_diag(sns.histplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.lineplot)

# %%
g = sns.PairGrid(data = tips)
g.map_diag(sns.histplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.lineplot)
#ไม่ได้แยกเพศ

# %%
sns.lmplot(data = tips, x = 'total_bill' , y = 'tip')
# Out:
# C:\Users\natty\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data = tips, x = 'total_bill' , y = 'tip',col = 'sex')
# Out:
# C:\Users\natty\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\natty\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data = tips, x = 'total_bill' , y = 'tip',row = 'sex')
# Out:
# C:\Users\natty\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\natty\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lmplot(data = tips, x = 'total_bill' , y = 'tip',col = 'sex',row = 'smoker')
# Out:
# C:\Users\natty\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\natty\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.FacetGrid(data = tips,col = 'sex', row = 'smoker')
g.map( sns.scatterplot ,'total_bill','tip')
# Out:
# C:\Users\natty\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[['total_bill','tip','size']]
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
tips[['total_bill','tip','size']].corr()
#ดูตัวเลขความสัมพันธ์ของแต่ละคอลัมน์
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips[['total_bill','tip','size']].corr(),cmap = 'coolwarm',annot = True)
# Out:
# <Axes: >
